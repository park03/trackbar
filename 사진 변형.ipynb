# %% [markdown]
# # 사진 줄이기

# %%
import cv2
import numpy as np

img=cv2.imread('img/puppy.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = cv2.pyrDown(img) # 사이즈 절반으로 줄이기. 두번 입력하면 더 작아짐

if img.ndim == 3:
    cv2.imshow("COLOR",img)
    
print(img.shape)
print(img.ndim, img2.ndim)

# cv2.imshow("result",img)
# cv2.imshow("result2",img2)
cv2.waitKey(0) #아무키나 누르면 종료됨. 
cv2.destroyAllWindows()
# Out:
# (108, 108, 3)
# 3 2

# %% [markdown]
# # 사진 위치 변경

# %%
img=cv2.imread('img/puppy.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

if img.ndim == 3:
    height, width, _ = img.shape 
elif img2.ndim == 2:
    height, width = img.shape
    
print(img.shape)
print(img.ndim, img2.ndim)


cv2.waitKey(0) #아무키나 누르면 종료됨. 
cv2.destroyAllWindows()
# Out:
# (215, 215, 3)
# 3 2

# %%
img=cv2.imread('55.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

if img.ndim == 3:
    height, width, _ = img.shape 
elif img2.ndim == 2:
    height, width = img.shape
    
print(img.shape)
print(img.ndim, img2.ndim)

# 이미지가 저장된 넘파이 배열의 너비와 높이를 구합니다
height,width = img.shape[:2]

cv2.waitKey(0) #아무키나 누르면 종료됨. 
cv2.destroyAllWindows()

# 이동변환행렬을 생성합니다. x방향으로 100픽셀, y방향으로 200픽셀 이동합니다.
M = np.array([[1,0,0], [0,1,300],[0,0,1]])

# 결과 이미지를 저장할 넘파이 배열을 입력 이미지와 같은 크기로 생성합니다.
dst = np.zeros(img.shape, dtype = np.uint8)

#이미지의 전체 픽셀을 스캔합니다.
for y in range(height - 1):
    for x in range(width-1):
        
        #현재 픽셀p의 좌표에 이동변환 행렬  M을 곱하여 이동시킨 좌표 p_를 구합니다
        p=np.array([x,y,1])
        p_=np.dot(M,p)
        
        # 이동한 위치인 p_ 에서 좌표 x_,y_를 정수 형태로 가져옵니다.
        x_,y_=p_[:2]
        x_=int(x_)
        y_=int(y_)
        
        # 입력 이미지 크기 내로 픽셀이 이동한 경우에만 결과 이미지를 저장할 넘파이 배열로 픽셀을 복사합니다.
        if x_ > 0 and x_ < width and y_ > 0 and y_ < height:
            dst[y_, x_]=img[y,x]
            
# 입력 이미지와 결과 이미지를 수평으로 연결하여 하나의 이미지로 만듭니다.
result = cv2.hconcat([img,dst])

cv2.imshow("image",result)
# cv2.imshow("iamge2",img2)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1185, 800, 3)
# 3 2

# %%
img=cv2.imread('img/dd.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


# 이미지가 저장된 넘파이 배열의 너비와 높이를 구합니다
height,width = img.shape[:2]

cv2.waitKey(0) #아무키나 누르면 종료됨. 
cv2.destroyAllWindows()

# 이동변환행렬을 생성합니다. x방향으로 100픽셀, y방향으로 200픽셀 이동합니다.
# M = np.array([[1,0,0], [0,1,300],[0,0,1]], dtype = float32) 
# dst=cv2.warpAffine(img, M, (width, height))

M = np.array([[1, 0, 0], [0, 1, 200]], dtype = float)
dst=cv2.warpAffine(img,M ,(width,height))

# 입력 이미지와 결과 이미지를 수평으로 연결하여 하나의 이미지로 만듭니다.
result = cv2.hconcat([img,dst,img,img,img,img])

cv2.imshow("image",result)
# cv2.imshow("iamge2",img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread('img/dd.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


# 이미지가 저장된 넘파이 배열의 너비와 높이를 구합니다
height,width = img.shape[:2]

cv2.waitKey(0) #아무키나 누르면 종료됨. 
cv2.destroyAllWindows()

# 이동변환행렬을 생성합니다. x방향으로 100픽셀, y방향으로 200픽셀 이동합니다.
# M = np.array([[1,0,0], [0,1,300],[0,0,1]], dtype = float32) 
# dst=cv2.warpAffine(img, M, (width, height))

M = np.array([[1, 0, 0], [0, 1, 200]], dtype = float)
dst=cv2.warpAffine(img,M ,(width,height))

# 입력 이미지와 결과 이미지를 수평으로 연결하여 하나의 이미지로 만듭니다.
result = cv2.hconcat([img,dst])

cv2.imshow("image",result)
# cv2.imshow("iamge2",img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 사진 회전

# %%
img=cv2.imread('img/dd.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

height,width = img.shape[:2]

angle=45

center=(height/2,width/2)

# getRotationMatrix2d함수를 사용하여 angle만큼 회전하는 회전변환  을 생성합니다.
rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1)

dst = cv2.warpAffine(img, rotation_matrix, (width, height))

result = cv2.hconcat([img,dst])

cv2.imshow("image",result)
cv2.waitKey(0)
# Out:
# 100

# %%
import cv2
import numpy as np

# %% [markdown]
# 가중치  비율을 이용해서 중간에 있는 값을 구함
# 양쪽에 선형적인 점
# binary type interploration

# %%
img=cv2.imread('img/dd.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img3=
dst = cv2.resize(img, (int(width*3),int(height*3)))

cv2.imshow("image",dst)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f4ab89b788d0> in <module>
#       4 img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       5 # img3=
# ----> 6 dst = cv2.resize(img, (int(width*3),int(height*3)))
#       7
#       8 cv2.imshow("image",dst)
#
# NameError: name 'width' is not defined

# %%
import cv2
import numpy as np


# (x,y)에 있는 픽셀을 위해 보간법을 적용하는 함수입니다.
def BilinearInterpolation(Q11, Q12, Q21, Q22, x1, x2, y1, y2, x, y):

    P = 1/((x2-x1)*(y2-y1))*(Q11*(x2-x)*(y2-y)+Q21*(x-x1)*(y2-y)+Q12*(x2-x)*(y-y1)*Q22*(x-x1)*(y-y1))

    return P


img = cv2.imread('img/dd.jpg',cv2.IMREAD_COLOR)
height,width = img.shape[:2]


# 0.5배 축소하는 변환행렬을 생성합니다. 
scale_factor = 0.5
new_width = int(width*scale_factor)
new_height = int(height*scale_factor)
scaling_matrix = np.array([[scale_factor, 0, 0], [0, scale_factor, 0], [0, 0, 1]])


# backward mapping을 사용하여 축소변환행렬 scaling_matrix을 이미지에 적용합니다. 
dst = np.zeros((new_height, new_width, img.shape[2]) , dtype=np.uint8)

for y in range(new_height):
    for x in range(new_width):
        new_p = np.array([x, y, 1])
        inv_scaling_matrix = np.linalg.inv(scaling_matrix)
        old_p = np.dot(inv_scaling_matrix, new_p)
        
        x_,y_ = old_p[:2]
        x_ = int(x_)
        y_ = int(y_)
        
        dst.itemset((y, x, 0), img.item(y_, x_, 0))
        dst.itemset((y, x, 1), img.item(y_, x_, 1))
        dst.itemset((y, x, 2), img.item(y_, x_, 2))


# 보간법을 적용합니다. 
dst2 = np.zeros((new_height, new_width, img.shape[2]) , dtype=np.uint8)

for y in range(new_height-1):
    for x in range(new_width-1):
        q11 = dst[y - 1, x - 1]
        q12 = dst[y + 1, x - 1]
        q21 = dst[y + 1, x + 1]
        q22 = dst[y - 1, x + 1]
        
        if dst[y, x].all() == 0:
            p = BilinearInterpolation(q11, q12, q21, q22, x - 1, x + 1, y - 1, y + 1, x, y);
            
        else:
            p = dst[y, x]
        
        dst2.itemset(y, x, 0, p[0])
        dst2.itemset(y, x, 1, p[1])
        dst2.itemset(y, x, 2, p[2])

cv2.imshow("result", dst2)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('55.jpg', cv2.IMREAD_COLOR)
height, width, channel = img.shape

img_scale_down = cv2.pyrDown(img)
height2, width2, channel = img_scale_down.shape

merge = np.zeros((height, width*2, channel),dtype=np.uint8)

merge[0:height, 0:width,:] = img
merge[0:height2, width:(width+width2)] = img_scale_down

fig = plt.figure(figsize=(12,9))

ax =  fig.add_subplot(1,2, 2)
ax.imshow(cv2.cvtColor(merge, cv2.COLOR_BGR2RGB))
ax.set_title('test')
ax.axis("off")
# Out:
# (-0.5, 1599.5, 1184.5, -0.5)

# %%
import cv2
import numpy as np


img = cv2.imread('img/dd.jpg',cv2.IMREAD_COLOR)
height,width = img.shape[:2]

# 이미지를 1.5배 확대합니다.
dst = cv2.resize(img, (int(width*1.5), int(height*1.5)));

cv2.imshow("result", dst)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # 적용

# %%
import cv2
import numpy as np


img = cv2.imread('img/dd.jpg',cv2.IMREAD_COLOR)
height,width = img.shape[:2]


scale_factor = 0.5
scaling_matrix = np.array([[scale_factor, 0, 0], [0, scale_factor, 0], [0, 0, 1]]) #이미지 크기 줄이기
translation_matrix = np.array([[1, 0, width/4], [0, 1, height/4], [0, 0, 1]]) # 위치이동
angle = -45 #돌리는 각도
radian = angle*np.pi/180
c = np.cos(radian)
s = np.sin(radian)
center_x = width / 2
center_y = height / 2
# getRotationMatrix2d함수를 사용하여 angle만큼 회전하는 회전변환  을 생성합니다.
rotation_matrix = np.array([[c, s, (1-c)*center_x-s*center_y], [-s, c, s*center_x+(1-c)*center_y], [0, 0, 1]])

# 정해진 순서대로 변환 행렬을 곱하여 하나의 행렬을 생성합니다. 
T = np.eye(3)
T = np.dot(scaling_matrix, T)
T = np.dot(translation_matrix, T)
T = np.dot(rotation_matrix, T)
print(T)

#파일 이미지 지정
dst = np.zeros((height, width, img.shape[2]) , dtype=np.uint8)

for y in range(height):
    for x in range(width):

             # 미리 구해놓은 변환행렬을 행렬곱 한번으로 적용합니다. 
             # 여기에서도 backward mapping을 사용합니다. 
        new_p = np.array([x, y, 1])
        inv_scaling_matrix = np.linalg.inv(T)
        old_p = np.dot(inv_scaling_matrix, new_p)

        x_,y_ = old_p[:2]
        x_ = int(x_)
        y_ = int(y_)

        if x_ > 0 and x_ < width and y_ > 0 and y_ < height:
            dst.itemset((y, x, 0), img.item(y_, x_, 0))
            dst.itemset((y, x, 1), img.item(y_, x_, 1))
            dst.itemset((y, x, 2), img.item(y_, x_, 2))

cv2.imshow("result", dst)
cv2.waitKey(0)
# Out:
# [[ 3.53553391e-01 -3.53553391e-01  4.19370951e+02]
#  [ 3.53553391e-01  3.53553391e-01  1.90964007e+02]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# -1
