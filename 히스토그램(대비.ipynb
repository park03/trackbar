# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img_color = cv2.imread("mon.png")
img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)

plt.hist(img_gray.ravel(), 256, [0,256]); 
plt.show()

# %% [markdown]
# 이미지 향상/개선

# %%
equ = cv2.equalizeHist(img_gray)
res = np.hstack((img_gray, equ))

cv2.imshow('src', res)
cv2.waitKey(0)

cv2.destroyAllWindows() #(대비 상승! 흐릿한 회색 이미지를 찐하게 만들어준다. )

plt.hist(res.ravel(), 256, [0,256]); 
plt.show()

# %% [markdown]
# Histogram Equalization : 이미지를 전처리하는 방법
